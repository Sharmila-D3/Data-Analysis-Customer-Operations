# %%
import pandas as pd

discount_data = pd.read_csv(r'C:\Users\YourPath\discount_campaign.csv')

# Display the first few rows to understand the structure
print(discount_data.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 discount_data = pd.read_csv(r'C:\Users\YourPath\discount_campaign.csv')
#       5 # Display the first few rows to understand the structure
#       6 print(discount_data.head())
#
# ...

# %%
import pandas as pd

discount_data = pd.read_csv(r'C:\Users\91770\Desktop\Data_Analysis_Assignment\data\discount_campaign.csv')

# Display the first few rows to understand the structure
print(discount_data.head())
# Out:
#    customer_id discount_applied  order_count_before  order_count_after  \
# 0         1286               No                   4                 11
# 1         1563              Yes                  10                  2
# 2         1289               No                   2                  8
# 3         1053               No                   4                  3
# 4         1516              Yes                  19                  2
#
#    total_spend_before  total_spend_after
# 0         1736.119038        3601.461583
# 1          923.649992         387.822968
# 2         3526.359734        9705.813801
# 3         1683.084961         326.592907
# 4         3746.981815        6747.656727

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the discount campaign dataset (adjust the file path as needed)
discount_data = pd.read_csv(r'C:\Users\91770\Desktop\Data_Analysis_Assignment\data\discount_campaign.csv')

# Display first few rows to confirm the data structure
print(discount_data.head())
# Out:
#    customer_id discount_applied  order_count_before  order_count_after  \
# 0         1286               No                   4                 11
# 1         1563              Yes                  10                  2
# 2         1289               No                   2                  8
# 3         1053               No                   4                  3
# 4         1516              Yes                  19                  2
#
#    total_spend_before  total_spend_after
# 0         1736.119038        3601.461583
# 1          923.649992         387.822968
# 2         3526.359734        9705.813801
# 3         1683.084961         326.592907
# 4         3746.981815        6747.656727

# %%
# Calculate percentage change in order count and total spend
discount_data['order_count_change_pct'] = ((discount_data['order_count_after'] - discount_data['order_count_before']) / discount_data['order_count_before']) * 100
discount_data['spend_change_pct'] = ((discount_data['total_spend_after'] - discount_data['total_spend_before']) / discount_data['total_spend_before']) * 100

# Display the updated DataFrame to verify the new columns
print(discount_data[['customer_id', 'discount_applied', 'order_count_change_pct', 'spend_change_pct']].head())
# Out:
#    customer_id discount_applied  order_count_change_pct  spend_change_pct
# 0         1286               No              175.000000        107.443240
# 1         1563              Yes              -80.000000        -58.011912
# 2         1289               No              300.000000        175.236066
# 3         1053               No              -25.000000        -80.595578
# 4         1516              Yes              -89.473684         80.082452

# %%
# Group the data by discount_applied and calculate the average metrics
summary = discount_data.groupby('discount_applied')[['order_count_before', 'order_count_after', 
                                                     'total_spend_before', 'total_spend_after', 
                                                     'order_count_change_pct', 'spend_change_pct']].mean()
print(summary)
# Out:
#                   order_count_before  order_count_after  total_spend_before  \
# discount_applied
# No                          9.826772          15.724409         2538.720034
# Yes                        10.130081          15.939024         2607.674516
#
#                   total_spend_after  order_count_change_pct  spend_change_pct
# discount_applied
# No                      5092.106617              214.285376        307.252098
# Yes                     5181.592918              180.674804        530.997234

# %%
# Set up a figure with two subplots side-by-side
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot average percentage change in order count
summary['order_count_change_pct'].plot(kind='bar', ax=axes[0], color=['skyblue', 'salmon'])
axes[0].set_title("Average % Change in Order Count")
axes[0].set_xlabel("Discount Applied")
axes[0].set_ylabel("Average % Change")
axes[0].set_ylim([min(summary['order_count_change_pct'])-10, max(summary['order_count_change_pct'])+10])

# Plot average percentage change in total spend
summary['spend_change_pct'].plot(kind='bar', ax=axes[1], color=['skyblue', 'salmon'])
axes[1].set_title("Average % Change in Total Spend")
axes[1].set_xlabel("Discount Applied")
axes[1].set_ylabel("Average % Change")
axes[1].set_ylim([min(summary['spend_change_pct'])-10, max(summary['spend_change_pct'])+10])

plt.tight_layout()
plt.show()
